# %% [markdown]
# ### Min-max strategy

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from tqdm import tqdm
from strategies import minmax
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Alex\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Single ticker backtester

# %%
ticker_name = "META"
period = "2y"
period_to_buy = 89
period_to_sell = 13

mm_strat = minmax.Minmax_strategy(ticker_name, period, period_to_buy, period_to_sell)
strategy_profit, classic_profit = mm_strat.backtester(logs=True)
# Out:
# Bought  2023-01-27 00:00:00  for  151.74000549316406
# Sold  2023-02-22 00:00:00  for  171.1199951171875
# Bought  2023-03-15 00:00:00  for  197.75
# Sold  2023-04-25 00:00:00  for  207.5500030517578
# Bought  2023-04-27 00:00:00  for  238.55999755859375
# Sold  2023-08-14 00:00:00  for  306.19000244140625
# Bought  2023-10-11 00:00:00  for  327.82000732421875

# %%
print("Strategy profit: ", strategy_profit)
print("Classic profit: ", classic_profit)
# Out:
# Strategy profit:  0.4207160943020658
# Classic profit:  -0.04163108636857905

# %%
# Multi ticker backtester

# %%
SP500 = ['ADBE' , 'ADP' , 'AES' , 'AFL' , 'A' , 'APD' , 'AKAM' , 'ALK' , 'ALB' , 'ARE' , 'ALGN' , 'ALLE' , 'LNT' , 'ALL' , 'GOOGL' , 'GOOG' , 'MO' , 'AMZN' , 'AMCR' , 'AMD' , 'AEE' , 'AAL' , 'AEP' , 'AXP' , 'AIG' , 'AMT' , 'AWK' , 'AMP' , 'AME' , 'AMGN' , 'APH' , 'ADI' , 'ANSS' , 'AON' , 'APA' , 'AAPL' , 'AMAT' , 'APTV' , 'ACGL' , 'ANET' , 'AJG' , 'AIZ' , 'T' , 'ATO' , 'ADSK' , 'AZO' , 'AVB' , 'AVY' , 'AXON' , 'BKR' , 'BALL' , 'BAC' , 'BBWI' , 'BAX' , 'BDX' , 'WRB' , 'BBY' , 'BIO' , 'TECH' , 'BIIB' , 'BLK' , 'BK' , 'BA' , 'BKNG' , 'BWA' , 'BXP' , 'BSX' , 'BMY' , 'AVGO' , 'BR' , 'BRO' ,'BG' , 'CHRW' , 'CDNS' , 'CZR' , 'CPT' , 'CPB' , 'COF' , 'CAH' , 'KMX' , 'CCL' , 'CARR' , 'CTLT' , 'CAT' , 'CBOE' , 'CBRE' , 'CDW' , 'CE' , 'COR' , 'CNC' , 'CNP' , 'CDAY' , 'CF' , 'CRL' , 'SCHW' , 'CHTR' , 'CVX' , 'CMG' , 'CB' , 'CHD' , 'CI' , 'CINF' , 'CTAS' , 'CSCO' , 'C' , 'CFG' , 'CLX' , 'CME' , 'CMS' , 'KO' , 'CTSH' , 'CL' , 'CMCSA' , 'CMA' , 'CAG' , 'COP' , 'ED' , 'STZ' , 'CEG' , 'COO' , 'CPRT' , 'GLW' , 'CTVA' , 'CSGP' , 'COST' , 'CTRA' , 'CCI' , 'CSX' , 'CMI' , 'CVS' , 'DHI' , 'DHR' , 'DRI' , 'DVA' , 'DE' , 'DAL' , 'XRAY' , 'DVN' , 'DXCM' , 'FANG' , 'DLR' , 'DFS' , 'DIS' , 'DG' , 'DLTR' , 'D' , 'DPZ' , 'DOV' , 'DOW' , 'DTE' , 'DUK' , 'DD' , 'DXC' , 'EMN' , 'ETN' , 'EBAY' , 'ECL' , 'EIX' , 'EW' , 'EA' , 'ELV' , 'LLY' , 'EMR' , 'ENPH' , 'ETR' , 'EOG' , 'EPAM' , 'EQT' , 'EFX' , 'EQIX' , 'EQR' , 'ESS' , 'EL' , 'ETSY' , 'EG' , 'EVRG' , 'ES' , 'EXC' , 'EXPE' , 'EXPD' , 'EXR' , 'XOM' , 'FFIV' , 'FDS' , 'FICO' , 'FAST' , 'FRT' , 'FDX' , 'FITB' , 'FSLR' , 'FE' , 'FIS' , 'FI' , 'FLT' , 'FMC' , 'F' , 'FTNT' , 'FTV' , 'FOXA' , 'FOX' , 'BEN' , 'FCX' , 'GRMN' , 'IT' , 'GEHC' , 'GEN' , 'GNRC' , 'GD' , 'GE' , 'GIS' , 'GM' , 'GPC' , 'GILD' , 'GL' , 'GPN' , 'GS' , 'HAL' , 'HIG' , 'HAS' , 'HCA' , 'PEAK' , 'HSIC' , 'HSY' , 'HES' , 'HPE' , 'HLT' , 'HOLX' , 'HD' , 'HON' , 'HRL' , 'HST' , 'HWM' , 'HPQ' , 'HUM' , 'HBAN' , 'HII' , 'IBM' , 'IEX' , 'IDXX' , 'ITW' , 'ILMN' , 'INCY' , 'IR' , 'PODD' , 'INTC' , 'ICE' , 'IFF' , 'IP' , 'IPG' , 'INTU' , 'ISRG' , 'IVZ' , 'INVH' , 'IQV' , 'IRM' , 'JBHT' , 'JKHY' , 'J' , 'JNJ' , 'JCI' , 'JPM' , 'JNPR' , 'K' , 'KVUE' , 'KDP' , 'KEY' , 'KEYS' , 'KMB' , 'KIM' , 'KMI' , 'KLAC' , 'KHC' , 'KR' , 'LHX' , 'LH' , 'LRCX' , 'LW' , 'LVS' , 'LDOS' , 'LEN' , 'LNC' , 'LIN' , 'LYV' , 'LKQ' , 'LMT' , 'L' , 'LOW' , 'LYB' , 'MTB' , 'MRO' , 'MPC' , 'MKTX' , 'MAR' , 'MMC' , 'MLM' , 'MAS' , 'MA' , 'MTCH' , 'MKC' , 'MCD' , 'MCK' , 'MDT' , 'MRK' , 'META' , 'MET' , 'MTD' , 'MGM' , 'MCHP' , 'MU' , 'MSFT' , 'MAA' , 'MRNA' , 'MHK' , 'MOH' , 'TAP' , 'MDLZ' , 'MPWR' , 'MNST' , 'MCO' , 'MS' , 'MOS' , 'MSI' , 'MSCI' , 'NDAQ' , 'NTAP' , 'NFLX' , 'NWL' , 'NEM' , 'NWSA' , 'NWS' , 'NEE' , 'NKE' , 'NI' , 'NDSN' , 'NSC' , 'NTRS' , 'NOC' , 'NCLH' , 'NRG' , 'NUE' , 'NVDA' , 'NVR' , 'NXPI' , 'ORLY' , 'OXY' , 'ODFL' , 'OMC' , 'ON' , 'OKE' , 'ORCL' , 'OGN' , 'OTIS' , 'PCAR' , 'PKG' , 'PANW' , 'PARA' , 'PH' , 'PAYX' , 'PAYC' , 'PYPL' , 'PNR' , 'PEP' , 'PFE' , 'PCG' , 'PM' , 'PSX' , 'PNW' , 'PXD' , 'PNC' , 'POOL' , 'PPG' , 'PPL' , 'PFG' , 'PG' , 'PGR' , 'PLD' , 'PRU' , 'PEG' , 'PTC' , 'PSA' , 'PHM' , 'QRVO' , 'PWR' , 'QCOM' , 'DGX' , 'RL' , 'RJF' , 'RTX' , 'O' , 'REG' , 'REGN' , 'RF' , 'RSG' , 'RMD' , 'RVTY' , 'RHI' , 'ROK' , 'ROL' , 'ROP' , 'ROST' , 'RCL' , 'SPGI' , 'CRM' , 'SBAC' , 'SLB' , 'STX' , 'SEE' , 'SRE' , 'NOW' , 'SHW' , 'SPG' , 'SWKS' , 'SJM' , 'SNA' , 'SEDG' , 'SO' , 'LUV' , 'SWK' , 'SBUX' , 'STT' , 'STLD' , 'STE' , 'SYK' , 'SYF' , 'SNPS' , 'SYY' , 'TMUS' , 'TROW' , 'TTWO' , 'TPR' , 'TRGP' , 'TGT' , 'TEL' , 'TDY' , 'TFX' , 'TER' , 'TSLA' , 'TXN' , 'TXT' , 'TMO' , 'TJX' , 'TSCO' , 'TT' , 'TDG' , 'TRV' , 'TRMB' , 'TFC' , 'TYL' , 'TSN' , 'USB' , 'UDR' , 'ULTA' , 'UNP' , 'UAL' , 'UPS' , 'URI' , 'UNH' , 'UHS' , 'VLO' , 'VTR' , 'VRSN' , 'VRSK' , 'VZ' , 'VRTX' , 'VFC' , 'VTRS' , 'VICI' , 'V' , 'VMC' , 'WAB' , 'WBA' , 'WMT' , 'WBD' , 'WM' , 'WAT' , 'WEC' , 'WFC' , 'WELL' , 'WST' , 'WDC' , 'WRK' , 'WY' , 'WHR' , 'WMB' , 'WTW' , 'GWW' , 'WYNN' , 'XEL' , 'XYL' , 'YUM' , 'ZBRA' , 'ZBH' , 'ZION' , 'ZTS']

# %%
minmax_results = pd.DataFrame()

for tick in tqdm(SP500, desc="Processing", unit="items"):
    mm_strat = minmax.Minmax_strategy(tick, "2y", 89, 13)
    strategy_profit, classic_profit = mm_strat.backtester(logs=False)
    minmax_results = minmax_results.append({"Ticker": tick, "MinMax Profit": strategy_profit, "Classic Profit": classic_profit}, ignore_index=True)
# Out:
# Processing: 100%|█████████████████████████████████████████████████████████████████| 494/494 [02:21<00:00,  3.50items/s]

# %%
minmax_results.head(5)
# Out:
#   Ticker  MinMax Profit  Classic Profit
# 0   ADBE       0.163492       -0.085400
# 1    ADP       0.105832        0.247976
# 2    AES      -0.026581       -0.423871
# 3    AFL       0.085722        0.545902
# 4      A      -0.080611       -0.261288

# %%
print("Mean min-max strategy profit: ", minmax_results["MinMax Profit"].mean())
print("Mean classic strategy profit: ", minmax_results["Classic Profit"].mean())
# Out:
# Mean min-max strategy profit:  -0.020541634006229038
# Mean classic strategy profit:  -0.012003718392429844

# %%
minmax_results["Profit Diff"] = minmax_results["MinMax Profit"] - minmax_results["Classic Profit"]

# %%
sorted_minmax_results = minmax_results.sort_values(by='Profit Diff', ascending=False)

# %%
sorted_minmax_results
# Out:
#     Ticker  MinMax Profit  Classic Profit  Profit Diff
# 359   PYPL       0.000000       -0.786807     0.786807
# 464    VFC       0.000000       -0.766674     0.766674
# 166   EPAM       0.153239       -0.604728     0.757968
# 297   MTCH      -0.113344       -0.779542     0.666198
# 355   PARA      -0.066376       -0.681404     0.615028
# ..     ...            ...             ...          ...
# 161    LLY       0.169453        1.634860    -1.465407
# 118    CEG       0.243774        2.048773    -1.804998
# 125   CTRA       0.434162             NaN          NaN
# 279    LEN       0.187549             NaN          NaN
# 307   MCHP      -0.106705             NaN          NaN
#
# [494 rows x 4 columns]

# %%
# Predict single

# %%
ticker_name = "META"
period = "2y"
period_to_buy = 89
period_to_sell = 13

mm_strat = minmax.Minmax_strategy(ticker_name, period, period_to_buy, period_to_sell)
pred = mm_strat.predict()

# %%
pred
# Out:
# 'Hold'

# %%
# Predict multi

# %%
pred_results = pd.DataFrame()

for tick in tqdm(SP500, desc="Processing", unit="items"):
    mm_strat = minmax.Minmax_strategy(tick, "2y", 89, 13)
    pred = mm_strat.predict()
    pred_results = pred_results.append({"Ticker": tick, "Recommendation": pred}, ignore_index=True)
# Out:
# Processing: 100%|█████████████████████████████████████████████████████████████████| 494/494 [02:16<00:00,  3.61items/s]

# %%
pred_results[pred_results["Recommendation"]=='Buy']
# Out:
#     Ticker Recommendation
# 3      AFL            Buy
# 13     ALL            Buy
# 29    AMGN            Buy
# 41     AIZ            Buy
# 68    AVGO            Buy
# 89     CNC            Buy
# 100     CI            Buy
# 107    CME            Buy
# 115    COP            Buy
# 118    CEG            Buy
# 125   CTRA            Buy
# 139   FANG            Buy
# 161    LLY            Buy
# 174     EG            Buy
# 185   FAST            Buy
# 207     GD            Buy
# 216    HAL            Buy
# 289    MRO            Buy
# 300    MCK            Buy
# 313    MOH            Buy
# 329    NWS            Buy
# 336    NOC            Buy
# 338    NRG            Buy
# 348    OKE            Buy
# 354   PANW            Buy
# 367    PXD            Buy
# 374    PGR            Buy
# 390   REGN            Buy
# 456    UNH            Buy
# 463   VRTX            Buy
# 483    WMB            Buy

# %% [markdown]
# ## RSI and MACD strategy

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from tqdm import tqdm
from strategies import rsi
import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Single ticker backtester

# %%
rs = rsi.RSI_strategy('V')
strategy_profit, classic_profit = rs.backtester(100, logs=True)
# Out:
# Bought  2023-06-16 00:00:00  for  228.48036193847656
# Sold  2023-09-15 00:00:00  for  241.07000732421875

# %%
print("Strategy profit: ", strategy_profit)
print("Classic profit: ", classic_profit)
# Out:
# Strategy profit:  0.0551016519710006
# Classic profit:  0.04854377854022317

# %%
# Create graph

# %%
rs.create_graph_v2()
# Out:
# <div>                            <div id="e771a2f6-6ce8-4c71-b236-bd51bf8f5c4d" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e771a2f6-6ce8-4c71-b236-bd51bf8f5c4d")) {                    Plotly.newPlot(                        "e771a2f6-6ce8-4c71-b236-bd51bf8f5c4d",                        [{"mode":"lines","name":"Main","x":["2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-10
# ...

# %%
# Predict

# %%
operations = pd.DataFrame()

for tick in tqdm(SP500, desc="Processing", unit="items"):
    rs = rsi.RSI_strategy(tick)
    result = rs.predict()
    
    operations = pd.concat([operations, result])
# Out:
# Processing: 100%|█████████████████████████████████████████████████████████████████| 494/494 [21:46<00:00,  2.64s/items]

# %%
operations
# Out:
#          Date Ticker Recommendation  Base Line  Signal Line        RSI  \
# 0  2023-10-13    AES           Sell  -1.210921    -1.183016  29.249987
# 0  2023-10-13    AFL            Buy   0.962126     0.604125  70.292412
# 0  2023-10-13    ALK           Sell  -1.820102    -1.704960  18.039964
# 0  2023-10-13   ALGN           Sell -16.803267   -15.508723  23.176618
# 0  2023-10-13    ALL            Buy   1.687638     1.226898  71.451003
# ..        ...    ...            ...        ...          ...        ...
# 0  2023-10-13    GWW            Buy   7.054786     2.333999  62.947671
# 0  2023-10-13    XEL            Buy   0.096547    -0.108609  56.180671
# 0  2023-10-13    YUM           Sell  -2.825989    -2.283410  29.656440
# 0  2023-10-13   ZBRA           Sell -10.375326    -8.961298  23.596990
# 0  2023-10-13    ZBH           Sell  -3.586114    -2.860038  29.968295
#
#     Histogram  Trend line slope
# 0   -0.027905          0.101000
# 0    0.358001          0.516000
# ...
